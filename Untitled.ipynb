# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print("hello there")
# Out:
# hello there

# %% [markdown]
# ---CELL BEGIN---
#
# You can do anything at https://html5zombo.com
#
# ---CELL END---

# %%
x = np.linspace(0, 10, 100)
y = np.random.rand(100)
plt.figure()
plt.plot(x, y)

plt.title('Random Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %% [markdown]
# dog with missing alt tag in markdown
#
# ![](data:image/jpeg;base64,...)

# %% [markdown]
# local image in markdown without alt tag
#
# ![h](testLocalImage.png)

# %% [markdown]
# local transparent image in markdown without alt tag
#
# ![h](testLocalImageTransp.png)

# %% [markdown]
# Plot with alt tag html
#
# <img alt="d" src="https://upload.wikimedia.org/wikipedia/commons/thumb/4/47/PNG_transparency_demonstration_1.png/640px-PNG_transparency_demonstration_1.png"></img>

# %% [markdown]
# Dog without alt tag html s
#
# ![h](testLocalImage.png)
#
# <img alt="" src="data:image/jpeg;base64,..."></img>
