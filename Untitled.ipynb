# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
print("hello there")
# Out:
# hello there

# %% [markdown]
# ---CELL BEGIN---
#
# You can do anything at https://html5zombo.com
#
# ---CELL END---

# %%
x = np.linspace(0, 10, 100)
y = np.random.rand(100)
plt.figure()
plt.plot(x, y)

plt.title('Random Plot')
plt.xlabel('X-axis')
plt.ylabel('Y-axis')

plt.show()

# %% [markdown]
# dog with an alt tag in markdown
#
# ![d](data:image/jpeg;base64,...)

# %% [markdown]
# local image in markdown without alt tag
#
# ![h](testLocalImage.png)

# %% [markdown]
# low visibility images with an alt tag in markdown
#
# ![n](https://htmlcolorcodes.com/assets/images/colors/off-white-color-solid-background-1920x1080.png)

# %% [markdown]
# Dog with alt tag html
#
# <img alt="hjj" src="data:image/jpeg;base64,..."></img>

# %% [markdown]
# Dog without alt tag html s
#
# <img alt="n" src="data:image/jpeg;base64,..."></img>
#
# <img alt="fix" src="data:image/jpeg;base64,..."></img>

# %% [markdown]
# Dog with alt tag html
#
#
# <img alt="" src="data:image/jpeg;base64,... ..."></img>
